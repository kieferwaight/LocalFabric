# %% [markdown]
# # local-ollama-tools: End-to-End Demo
#
# This notebook demonstrates all steps from the `local-ollama-tools` README, including installation, model setup, and function usage.

# %% [markdown]
# ## 1. Install Dependencies
#
# Install Python dependencies from `requirements.txt` using pip.

# %%
# Install Python dependencies
# !pip install -r requirements.txt

# %% [markdown]
# ## 2. Start Ollama Server
#
# Start the Ollama server in the background. (You only need to do this once per machine/session.)

# %%
# Start Ollama server (run in background, only once per session)
# !ollama serve &

# %% [markdown]
# ## 3. Pull Chat-Capable Ollama Model
#
# Pull the `qwen2.5:7b` model (or another chat-capable model) for use with local summarization.

# %%
# Pull the qwen2.5:7b model (or any chat-capable model)
# !ollama pull qwen2.5:7b

# %% [markdown]
# ## 4. Import Local Tools Functions
#
# Import `local_research_scaffold` and `run_local_tests` from the `local_tools` module.

# %%
# Import the local tools functions
from local_tools import local_research_scaffold, run_local_tests

# %% [markdown]
# ## 5. Run `local_research_scaffold` with a URL
#
# Call `local_research_scaffold` with a URL and print the result.

# %%
# Run local_research_scaffold with a URL
result_url = local_research_scaffold("https://raw.githubusercontent.com/modelcontextprotocol/python-sdk/main/README.md")
print(result_url)

# %% [markdown]
# ## 6. Run `local_research_scaffold` with a Topic
#
# Call `local_research_scaffold` with a topic string and print the result.

# %%
# Run local_research_scaffold with a topic string
result_topic = local_research_scaffold("mcp python sdk quickstart")
print(result_topic)

# %% [markdown]
# ## 7. Run `run_local_tests` with a Custom Command
#
# Call `run_local_tests` with a custom shell command (e.g., `pytest -k smoke`) and print the output.

# %%
# Run run_local_tests with a custom command
result_tests = run_local_tests("pytest -k smoke")
print(result_tests)

# %% [markdown]
# ## 8. Run End-to-End Smoke Test
#
# Run the end-to-end smoke test using `python3 test_runner.py`.

# %%
# Run the end-to-end smoke test
# !python3 test_runner.py

# %% [markdown]
# ## 9. Run Pytest on test_local_tools.py
#
# Run pytest on `test_local_tools.py` with verbose output.

# %%
# Run pytest on test_local_tools.py with verbose output
# !python3 -m pytest test_local_tools.py -v
