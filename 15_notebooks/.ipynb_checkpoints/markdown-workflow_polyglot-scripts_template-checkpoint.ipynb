# %% [markdown]
# # Template Notebook: Polyglot Scripts
# Template for testing polyglot script based markdown workflows

# %% [markdown]
# ## Markdown Definition
#
# Define markdown file as variable

# %%
md_definition = """
---
id: tests.polyglot
inputs:
  name:
    type: string
    required: true
---

# Polyglot

```bash {id: shell-step}
echo "shell sees {{ name }}"
```

```python {id: py-step}
import os, json
json.dump({"py_saw": "{{ name }}"}, open(os.environ["STATE_FILE"], "w"))
```
"""
print(md_definition)
# Out:
# ---
# id: tests.polyglot
# inputs:
#   name:
#     type: string
#     required: true
# ---
#
# # Polyglot
#
# ```bash {id: shell-step}
# echo "shell sees {{ name }}"
# ```
#
# ```python {id: py-step}
# import os, json
# json.dump({"py_saw": "{{ name }}"}, open(os.environ["STATE_FILE"], "w"))
# ```

# %% [markdown]
# ## Input Definitions
#
# Define the inputs

# %%
inputs = {
    "name": "test-name"
}

print(inputs)
# Out:
# {'name': 'test-name'}

# %% [markdown]
# ## Run
#
# Call execution using the template provided above

# %%
# Run md defintion with inputs
